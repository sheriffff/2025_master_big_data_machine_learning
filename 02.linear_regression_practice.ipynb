# %% [markdown]
# # Regresión lineal: práctica y ejercicios

# %% [markdown]
# **NOTAS**
#  - Hay muchas formas de resolver cada problema, encuentra la tuya.
#  - Crea las celdas extra que necesites.
#  - Recuerda que una celda puede ser de tipo Código, o de tipo Markdown. Utiliza las segundas para escribir texto y explicaciones si lo precisas.
#  - Intenta crear variables a la hora de resolver los ejercicios.
#  - Puedes apoyarte en internet: todos los programadores lo hacemos a diario.

# %% [markdown]
# Importamos el dataset *california housing*

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing

# %%
california_housing = fetch_california_housing(as_frame=True)
df = california_housing.frame

# %% [markdown]
# Para nuestro ejercicio de hoy, vamos a eliminar algunos datos de entrada

# %%
df = df[df.MedHouseVal < 5]

# %%
df.shape
# Out:
# (19648, 9)

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %% [markdown]
# **El objetivo del ejercicio será predecir `MedHouseVal` en función de otras variables**

# %% [markdown]
# **La métrica a optimizar será el root mean squared error (RMSE)**

# %% [markdown]
# ## Exploración de datos

# %%
print(california_housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# A household is a group of people residing within a home. Since the average
# number of rooms and bedrooms in this dataset are provided per household, these
# columns may take surprisingly large values for block groups with few households
# and many empty houses, such as vacation resorts.
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. rubric:: References
#
# - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#   Statistics and Probability Letters, 33:291-297, 1997.

# %% [markdown]
# Cada fila es un bloque de casas de California

# %% [markdown]
# Explora el dataset como consideres, acompañándo el análisis de plots univariantes / bivariantes

# %% [markdown]
# Presta especial atención a las variables `MedInc`, `HouseAge`, `AveRooms` y `MedHouseVal`

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df.MedHouseVal)
# Out:
# <Axes: xlabel='MedHouseVal', ylabel='Count'>

# %%
df.corr().style.background_gradient(cmap='Reds', vmin=-1, vmax=0.7)
# Out:
# <style type="text/css">
# #T_e122b_row0_col0, #T_e122b_row1_col1, #T_e122b_row2_col2, #T_e122b_row2_col3, #T_e122b_row3_col2, #T_e122b_row3_col3, #T_e122b_row4_col4, #T_e122b_row5_col5, #T_e122b_row6_col6, #T_e122b_row7_col7, #T_e122b_row8_col8 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e122b_row0_col1, #T_e122b_row1_col0 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_e122b_row0_col2, #T_e122b_row2_col0 {
#   background-color: #c2161b;
#   color: #f1f1f1;
# }
# #T_e122b_row0_col3, #T_e122b_row2_col4, #T_e122b_row3_col0, #T_e122b_row3_col4, #T_e122b_row4_col2, #T_e122b_row4_col3 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_e122b_row0_col4, #T_e122b_row4_col0 {
#   background-color: #f0402f;
#   color: #f1f1f1;
# }
# #T_e122b_row0_col5, #T_e122b_row5_col0 {
#   background-color: #f14331;
#   color: #f1f1f1;
# }
# #T_e122b_row0_col6, #T_e122b_row6_col0 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_e122b_row0_col7, #T_e122b_row2_col5, #T_e122b_row3_col5, #T_e122b_row5_col2, #T_e122b_row5_col3, #T_e122b_row7_col0 {
#   background-color: #f34a36;
#   color: #f1f1f1;
# }
# #T_e122b_row0_col8, #T_e122b_row8_col0 {
#   background-color: #77040f;
#   color: #f1f1f1;
# }
# #T_e122b_row1_col2, #T_e122b_row2_col1 {
#   background-color: #fb7050;
#   color: #f1f1f1;
# }
# #T_e122b_row1_col3, #T_e122b_row3_col1 {
#   background-color: #f75c41;
#   color: #f1f1f1;
# }
# #T_e122b_row1_col4, #T_e122b_row4_col1 {
#   background-color: #fc8565;
#   color: #f1f1f1;
# }
# #T_e122b_row1_col5, #T_e122b_row3_col7, #T_e122b_row4_col8, #T_e122b_row5_col1, #T_e122b_row7_col3, #T_e122b_row8_col4 {
#   background-color: #f24633;
#   color: #f1f1f1;
# }
# #T_e122b_row1_col6, #T_e122b_row6_col1 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_e122b_row1_col7, #T_e122b_row7_col1 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# #T_e122b_row1_col8, #T_e122b_row8_col1 {
#   background-color: #ee3a2c;
#   color: #f1f1f1;
# }
# #T_e122b_row2_col6, #T_e122b_row6_col2 {
#   background-color: #e53228;
#   color: #f1f1f1;
# }
# #T_e122b_row2_col7, #T_e122b_row7_col2 {
#   background-color: #f44f39;
#   color: #f1f1f1;
# }
# #T_e122b_row2_col8, #T_e122b_row8_col2 {
#   background-color: #e63328;
#   color: #f1f1f1;
# }
# #T_e122b_row3_col6, #T_e122b_row4_col5, #T_e122b_row5_col4, #T_e122b_row6_col3 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_e122b_row3_col8, #T_e122b_row8_col3 {
#   background-color: #f6563d;
#   color: #f1f1f1;
# }
# #T_e122b_row4_col6, #T_e122b_row6_col4 {
#   background-color: #f96245;
#   color: #f1f1f1;
# }
# #T_e122b_row4_col7, #T_e122b_row7_col4 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_e122b_row5_col6, #T_e122b_row5_col7, #T_e122b_row6_col5, #T_e122b_row7_col5 {
#   background-color: #f34935;
#   color: #f1f1f1;
# }
# #T_e122b_row5_col8, #T_e122b_row8_col5 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_e122b_row6_col7, #T_e122b_row7_col6 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_e122b_row6_col8, #T_e122b_row8_col6 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_e122b_row7_col8, #T_e122b_row8_col7 {
#   background-color: #f5533b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e122b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e122b_level0_col0" class="col_heading level0 col0" >MedInc</th>
#       <th id="T_e122b_level0_col1" class="col_heading level0 col1" >HouseAge</th>
#       <th id="T_e122b_level0_col2" class="col_heading level0 col2" >AveRooms</th>
#       <th id="T_e122b_level0_col3" class="col_heading level0 col3" >AveBedrms</th>
#       <th id="T_e122b_level0_col4" class="col_heading level0 col4" >Population</th>
#       <th id="T_e122b_level0_col5" class="col_heading level0 col5" >AveOccup</th>
#       <th id="T_e122b_level0_col6" class="col_heading level0 col6" >Latitude</th>
#       <th id="T_e122b_level0_col7" class="col_heading level0 col7" >Longitude</th>
#       <th id="T_e122b_level0_col8" class="col_heading level0 col8" >MedHouseVal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e122b_level0_row0" class="row_heading level0 row0" >MedInc</th>
#       <td id="T_e122b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e122b_row0_col1" class="data row0 col1" >-0.195542</td>
#       <td id="T_e122b_row0_col2" class="data row0 col2" >0.325739</td>
#       <td id="T_e122b_row0_col3" class="data row0 col3" >-0.065418</td>
#       <td id="T_e122b_row0_col4" class="data row0 col4" >0.042576</td>
#       <td id="T_e122b_row0_col5" class="data row0 col5" >0.026172</td>
#       <td id="T_e122b_row0_col6" class="data row0 col6" >-0.078135</td>
#       <td id="T_e122b_row0_col7" class="data row0 col7" >-0.008992</td>
#       <td id="T_e122b_row0_col8" class="data row0 col8" >0.646719</td>
#     </tr>
#     <tr>
#       <th id="T_e122b_level0_row1" class="row_heading level0 row1" >HouseAge</th>
#       <td id="T_e122b_row1_col0" class="data row1 col0" >-0.195542</td>
#       <td id="T_e122b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e122b_row1_col2" class="data row1 col2" >-0.180816</td>
#       <td id="T_e122b_row1_col3" class="data row1 col3" >-0.084755</td>
#       <td id="T_e122b_row1_col4" class="data row1 col4" >-0.294911</td>
#       <td id="T_e122b_row1_col5" class="data row1 col5" >0.015001</td>
#       <td id="T_e122b_row1_col6" class="data row1 col6" >0.006083</td>
#       <td id="T_e122b_row1_col7" class="data row1 col7" >-0.101740</td>
#       <td id="T_e122b_row1_col8" class="data row1 col8" >0.065139</td>
#     </tr>
#     <tr>
#       <th id="T_e122b_level0_row2" class="row_heading level0 row2" >AveRooms</th>
#       <td id="T_e122b_row2_col0" class="data row2 col0" >0.325739</td>
#       <td id="T_e122b_row2_col1" class="data row2 col1" >-0.180816</td>
#       <td id="T_e122b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e122b_row2_col3" class="data row2 col3" >0.842641</td>
#       <td id="T_e122b_row2_col4" class="data row2 col4" >-0.068886</td>
#       <td id="T_e122b_row2_col5" class="data row2 col5" >-0.005278</td>
#       <td id="T_e122b_row2_col6" class="data row2 col6" >0.121036</td>
#       <td id="T_e122b_row2_col7" class="data row2 col7" >-0.029497</td>
#       <td id="T_e122b_row2_col8" class="data row2 col8" >0.111581</td>
#     </tr>
#     <tr>
#       <th id="T_e122b_level0_row3" class="row_heading level0 row3" >AveBedrms</th>
#       <td id="T_e122b_row3_col0" class="data row3 col0" >-0.065418</td>
#       <td id="T_e122b_row3_col1" class="data row3 col1" >-0.084755</td>
#       <td id="T_e122b_row3_col2" class="data row3 col2" >0.842641</td>
#       <td id="T_e122b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_e122b_row3_col4" class="data row3 col4" >-0.069265</td>
#       <td id="T_e122b_row3_col5" class="data row3 col5" >-0.006593</td>
#       <td id="T_e122b_row3_col6" class="data row3 col6" >0.073421</td>
#       <td id="T_e122b_row3_col7" class="data row3 col7" >0.013105</td>
#       <td id="T_e122b_row3_col8" class="data row3 col8" >-0.061480</td>
#     </tr>
#     <tr>
#       <th id="T_e122b_level0_row4" class="row_heading level0 row4" >Population</th>
#       <td id="T_e122b_row4_col0" class="data row4 col0" >0.042576</td>
#       <td id="T_e122b_row4_col1" class="data row4 col1" >-0.294911</td>
#       <td id="T_e122b_row4_col2" class="data row4 col2" >-0.068886</td>
#       <td id="T_e122b_row4_col3" class="data row4 col3" >-0.069265</td>
#       <td id="T_e122b_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_e122b_row4_col5" class="data row4 col5" >0.070084</td>
#       <td id="T_e122b_row4_col6" class="data row4 col6" >-0.113457</td>
#       <td id="T_e122b_row4_col7" class="data row4 col7" >0.100989</td>
#       <td id="T_e122b_row4_col8" class="data row4 col8" >0.013592</td>
#     </tr>
#     <tr>
#       <th id="T_e122b_level0_row5" class="row_heading level0 row5" >AveOccup</th>
#       <td id="T_e122b_row5_col0" class="data row5 col0" >0.026172</td>
#       <td id="T_e122b_row5_col1" class="data row5 col1" >0.015001</td>
#       <td id="T_e122b_row5_col2" class="data row5 col2" >-0.005278</td>
#       <td id="T_e122b_row5_col3" class="data row5 col3" >-0.0

# %%
sns.scatterplot(x=df.MedInc, y=df.MedHouseVal, s=3)
# Out:
# <Axes: xlabel='MedInc', ylabel='MedHouseVal'>

# %% [markdown]
# ## Modelos predictivos

# %% [markdown]
# Queremos predecir `MedHouseVal`

# %% [markdown]
# ### Monta un modelo dummy

# %% [markdown]
# Solemos hacerlo para usarlo como baseline:
#
# consiste en asignar a todos los bloques el precio medio
#
# Evalúa su performance (RMSe)

# %% [markdown]
# ### Monta un modelo con un solo predictor: `HouseAge`

# %% [markdown]
# Y evalúa su performance

# %%
from sklearn.linear_model import LinearRegression

# %%
sns.histplot(x=df.HouseAge, y=df.MedHouseVal)
# Out:
# <Axes: xlabel='HouseAge', ylabel='MedHouseVal'>

# %%
lr = LinearRegression()

# %%
lr.fit(
    X=df[["HouseAge"]],
    y=df.MedHouseVal
)
# Out:
# LinearRegression()

# %%
df_temp = df[["HouseAge", "MedHouseVal"]].copy()

# %%
df_temp.head()
# Out:
#    HouseAge  MedHouseVal
# 0      41.0        4.526
# 1      21.0        3.585
# 2      52.0        3.521
# 3      52.0        3.413
# 4      52.0        3.422

# %%
df_temp["pred_val"] = lr.predict(df_temp[["HouseAge"]]).round(3)

# %%
df_temp.head(10)
# Out:
#    HouseAge  MedHouseVal  pred_val
# 0      41.0        4.526     1.984
# 1      21.0        3.585     1.883
# 2      52.0        3.521     2.040
# 3      52.0        3.413     2.040
# 4      52.0        3.422     2.040
# 5      52.0        2.697     2.040
# 6      52.0        2.992     2.040
# 7      52.0        2.414     2.040
# 8      42.0        2.267     1.989
# 9      52.0        2.611     2.040

# %%
mse = ((df_temp.MedHouseVal - df_temp.pred_val) ** 2).mean().round(3)

# %%
mse
# Out:
# np.float64(0.939)

# %% [markdown]
# ### Monta un modelo con un solo predictor: `MedInc`

# %% [markdown]
# Y evalúa su performance

# %% [markdown]
# ### Monta un modelo con los 3 predictores `MedInc`, `HouseAge`, `AveRooms`

# %% [markdown]
# Y evalúa su performance

# %% [markdown]
# ### Monta un modelo con todas las variables como predictoras

# %% [markdown]
# Y evalúa su performance

# %% [markdown]
# En qué bloques de casas comete mayor error tu modelo?
